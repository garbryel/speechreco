# %%
import tensorflow as tf

# Load model dari file .h5
model = tf.keras.models.load_model("model/mymodele.h5")

# Konversi ke format TFLite dengan opsi tambahan
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,       # Ops bawaan TFLite
    tf.lite.OpsSet.SELECT_TF_OPS          # Ops tambahan dari TensorFlow (agar LSTM dan TensorList bisa diproses)
]
converter._experimental_lower_tensor_list_ops = False  # Hindari konversi TensorList secara paksa

# Konversi
tflite_model = converter.convert()

# Simpan hasil .tflite
with open("mymodele.tflite", "wb") as f:
    f.write(tflite_model)

print("Konversi selesai! File disimpan sebagai mymodele.tflite")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\gabry\AppData\Local\Temp\tmp8ulcyuot\assets
# INFO:tensorflow:Assets written to: C:\Users\gabry\AppData\Local\Temp\tmp8ulcyuot\assets
# Konversi selesai! File disimpan sebagai mymodele.tflite

# %%
import tensorflow as tf

interpreter = tf.lite.Interpreter(model_path='mymodele.tflite')
interpreter.allocate_tensors()
tensor_details = interpreter.get_tensor_details()
for tensor in tensor_details:
    print(tensor)
# Out:
# {'name': 'serving_default_masking_input:0', 'index': 0, 'shape': array([  1, 930,  13]), 'shape_signature': array([ -1, 930,  13]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/masking/Squeeze', 'index': 1, 'shape': array([2]), 'shape_signature': array([2]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_1', 'index': 2, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_11', 'index': 3, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_2', 'index': 4, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_12', 'index': 5, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_13', 'index': 6, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_21', 'index': 7, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_22', 'index': 8, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2Stack/TensorListStack/element_shape', 'index': 9, 'shape': array([2]), 'shape_signature': array([2]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2Stack/TensorListStack/element_shape1', 'index': 10, 'shape': array([2]), 'shape_signature': array([2]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2Stack/TensorListStack/element_shape2', 'index': 11, 'shape': array([2]), 'shape_signature': array([2]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split/split_dim', 'index': 12, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'time', 'index': 13, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'transpose/perm', 'index': 14, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice', 'index': 15, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/Read_2/ReadVariableOp', 'index': 16, 'shape': array([512]), 'shape_signature': array([512]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_2/Read_2/ReadVariableOp', 'index': 17, 'shape': array([128]), 'shape_signature': array([128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_1/Read_2/ReadVariableOp', 'index': 18, 'shape': array([256]), 'shape_signature': array([256]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/dense/BiasAdd/ReadVariableOp', 'index': 19, 'shape': array([64]), 'shape_signature': array([64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/dense_1/BiasAdd/ReadVariableOp', 'index': 20, 'shape': array([7]), 'shape_signature': array([7]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/strided_slice/stack', 'index': 21, 'shape': array([1]), 'shape_signature': array([1]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/strided_slice/stack_1', 'index': 22, 'shape': array([1]), 'shape_signature': array([1]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/zeros/Const', 'index': 23, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/zeros/packed/1', 'index': 24, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_1/zeros/packed/1', 'index': 25, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_2/zeros/packed/1', 'index': 26, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/masking/Any/reduction_indices', 'index': 27, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul_11', 'index': 28, 'shape': array([256,  64]), 'shape_signature': array([256,  64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul', 'index': 29, 'shape': array([256, 128]), 'shape_signature': array([256, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul_12', 'index': 30, 'shape': array([128,  32]), 'shape_signature': array([128,  32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul1', 'index': 31, 'shape': array([128,  64]), 'shape_signature': array([128,  64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul_13', 'index': 32, 'shape': array([512, 128]), 'shape_signature': array([512, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul2', 'index': 33, 'shape': array([512,  13]), 'shape_signature': array([512,  13]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/dense/MatMul', 'index': 34, 'shape': array([64, 32]), 'shape_signature': array([64, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/dense_1/MatMul', 'index': 35, 'shape': array([ 7, 64]), 'shape_signature': array([ 7, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/masking/NotEqual', 'index': 36, 'shape': array([  1, 930,  13]), 'shape_signature': array([ -1, 930,  13]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/masking/Any', 'index': 37, 'shape': array([  1, 930,   1]), 'shape_signature': array([ -1, 930,   1]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/masking/Cast', 'index': 38, 'shape': array([  1, 930,   1]), 'shape_signature': array([ -1, 930,   1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/masking/mul', 'index': 39, 'shape': array([  1, 930,  13]), 'shape_signature': array([ -1, 930,  13]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/Shape', 'index': 40, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/strided_slice', 'index': 41, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/zeros/packed', 'index': 42, 'shape': array([2]), 'shape_signature': array([2]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm/zeros', 'index': 43, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/masking/Squeeze1', 'index': 44, 'shape': array([  1, 930]), 'shape_signature': array([ -1, 930]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'ExpandDims', 'index': 45, 'shape': array([  1, 930,   1]), 'shape_signature': array([ -1, 930,   1]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul_14', 'index': 46, 'shape': array([  1, 512]), 'shape_signature': array([ -1, 512]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'transpose', 'index': 47, 'shape': array([930,   1,  13]), 'shape_signature': array([930,  -1,  13]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2_1', 'index': 48, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.object_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_14', 'index': 49, 'shape': array([ 1, 13]), 'shape_signature': array([-1, 13]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul3', 'index': 50, 'shape': array([  1, 512]), 'shape_signature': array([ -1, 512]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'add', 'index': 51, 'shape': array([  1, 512]), 'shape_signature': array([ -1, 512]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'BiasAdd', 'index': 52, 'shape': array([  1, 512]), 'shape_signature': array([ -1, 512]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split', 'index': 53, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split1', 'index': 54, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split2', 'index': 55, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split3', 'index': 56, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid', 'index': 57, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid_1', 'index': 58, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul', 'index': 59, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid_2', 'index': 60, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Tanh', 'index': 61, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul_1', 'index': 62, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'add_1', 'index': 63, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Tanh_1', 'index': 64, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul_2', 'index': 65, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'zeros_like', 'index': 66, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'transpose_1', 'index': 67, 'shape': array([930,   1,   1]), 'shape_signature': array([930,  -1,   1]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while', 'index': 68, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while1', 'index': 69, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while2', 'index': 70, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.object_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while3', 'index': 71, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while4', 'index': 72, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while5', 'index': 73, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while6', 'index': 74, 'shape': array([930,   1,   1]), 'shape_signature': array([930,  -1,   1]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while7', 'index': 75, 'shape': array([930,   1,  13]), 'shape_signature': array([930,  -1,  13]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2Stack/TensorListStack', 'index': 76, 'shape': array([  1,   1, 128]), 'shape_signature': array([ -1,  -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'transpose_2', 'index': 77, 'shape': array([  1,   1, 128]), 'shape_signature': array([ -1,  -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_1/Shape', 'index': 78, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_1/strided_slice', 'index': 79, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_1/zeros/packed', 'index': 80, 'shape': array([2]), 'shape_signature': array([2]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_1/zeros', 'index': 81, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul_15', 'index': 82, 'shape': array([  1, 256]), 'shape_signature': array([ -1, 256]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Shape', 'index': 83, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice1', 'index': 84, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2_11', 'index': 85, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.object_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_15', 'index': 86, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul4', 'index': 87, 'shape': array([  1, 256]), 'shape_signature': array([ -1, 256]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'add1', 'index': 88, 'shape': array([  1, 256]), 'shape_signature': array([ -1, 256]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'BiasAdd1', 'index': 89, 'shape': array([  1, 256]), 'shape_signature': array([ -1, 256]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split4', 'index': 90, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split5', 'index': 91, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split6', 'index': 92, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split7', 'index': 93, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid1', 'index': 94, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid_11', 'index': 95, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul1', 'index': 96, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid_21', 'index': 97, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Tanh1', 'index': 98, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul_11', 'index': 99, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'add_11', 'index': 100, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Tanh_11', 'index': 101, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul_21', 'index': 102, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'zeros_like1', 'index': 103, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while8', 'index': 104, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while9', 'index': 105, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while10', 'index': 106, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.object_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while11', 'index': 107, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while12', 'index': 108, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while13', 'index': 109, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while14', 'index': 110, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while15', 'index': 111, 'shape': array([930,   1,   1]), 'shape_signature': array([930,  -1,   1]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while16', 'index': 112, 'shape': array([  1,   1, 128]), 'shape_signature': array([ -1,  -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2Stack/TensorListStack1', 'index': 113, 'shape': array([ 1,  1, 64]), 'shape_signature': array([-1, -1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'transpose_21', 'index': 114, 'shape': array([ 1,  1, 64]), 'shape_signature': array([-1, -1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_2/Shape', 'index': 115, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_2/strided_slice', 'index': 116, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_2/zeros/packed', 'index': 117, 'shape': array([2]), 'shape_signature': array([2]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/lstm_2/zeros', 'index': 118, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2_12', 'index': 119, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.object_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul_16', 'index': 120, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Shape1', 'index': 121, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice2', 'index': 122, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_16', 'index': 123, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'MatMul5', 'index': 124, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'add2', 'index': 125, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'BiasAdd2', 'index': 126, 'shape': array([  1, 128]), 'shape_signature': array([ -1, 128]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split8', 'index': 127, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split9', 'index': 128, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split10', 'index': 129, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'split11', 'index': 130, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid2', 'index': 131, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid_12', 'index': 132, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul2', 'index': 133, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Sigmoid_22', 'index': 134, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Tanh2', 'index': 135, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul_12', 'index': 136, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'add_12', 'index': 137, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'Tanh_12', 'index': 138, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'mul_22', 'index': 139, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'zeros_like2', 'index': 140, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while17', 'index': 141, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while18', 'index': 142, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while19', 'index': 143, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.object_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while20', 'index': 144, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while21', 'index': 145, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while22', 'index': 146, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while23', 'index': 147, 'shape': array([], dtype=int32), 'shape_signature': array([], dtype=int32), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while24', 'index': 148, 'shape': array([930,   1,   1]), 'shape_signature': array([930,  -1,   1]), 'dtype': <class 'numpy.bool_'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'while25', 'index': 149, 'shape': array([ 1,  1, 64]), 'shape_signature': array([-1, -1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'TensorArrayV2Stack/TensorListStack2', 'index': 150, 'shape': array([ 1,  1, 32]), 'shape_signature': array([ 1, -1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'strided_slice_23', 'index': 151, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/dense/MatMul;sequential/dense/Relu;sequential/dense/BiasAdd', 'index': 152, 'shape': array([ 1, 64]), 'shape_signature': array([-1, 64]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'sequential/dense_1/MatMul;sequential/dense_1/BiasAdd', 'index': 153, 'shape': array([1, 7]), 'shape_signature': array([-1,  7]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'StatefulPartitionedCall:0', 'index': 154, 'shape': array([1, 7]), 'shape_signature': array([-1,  7]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': '', 'index': 155, 'shape': array([3]), 'shape_signature': array([3]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': '', 'index': 156, 'shape': array([1]), 'shape_signature': array([1]), 'dtype': <class 'numpy.int32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}

# %%
import tensorflow as tf

interpreter = tf.lite.Interpreter(model_path='mymodele.tflite')
interpreter.allocate_tensors()
for op in interpreter._get_ops_details():
    print(op)
# Out:
# {'index': 0, 'op_name': 'NOT_EQUAL', 'inputs': array([ 0, 23]), 'outputs': array([36])}
# {'index': 1, 'op_name': 'REDUCE_ANY', 'inputs': array([36, 27]), 'outputs': array([37])}
# {'index': 2, 'op_name': 'CAST', 'inputs': array([37]), 'outputs': array([38])}
# {'index': 3, 'op_name': 'MUL', 'inputs': array([ 0, 38]), 'outputs': array([39])}
# {'index': 4, 'op_name': 'SHAPE', 'inputs': array([39]), 'outputs': array([40])}
# {'index': 5, 'op_name': 'STRIDED_SLICE', 'inputs': array([40, 21, 22, 22]), 'outputs': array([41])}
# {'index': 6, 'op_name': 'PACK', 'inputs': array([41, 24]), 'outputs': array([42])}
# {'index': 7, 'op_name': 'FILL', 'inputs': array([42, 23]), 'outputs': array([43])}
# {'index': 8, 'op_name': 'RESHAPE', 'inputs': array([37,  1]), 'outputs': array([44])}
# {'index': 9, 'op_name': 'EXPAND_DIMS', 'inputs': array([44, 27]), 'outputs': array([45])}
# {'index': 10, 'op_name': 'FULLY_CONNECTED', 'inputs': array([43, 32, -1]), 'outputs': array([46])}
# {'index': 11, 'op_name': 'TRANSPOSE', 'inputs': array([39, 14]), 'outputs': array([47])}
# {'index': 12, 'op_name': 'FlexTensorListReserve', 'inputs': array([11, 15]), 'outputs': array([48])}
# {'index': 13, 'op_name': 'STRIDED_SLICE', 'inputs': array([47,  2,  3,  4]), 'outputs': array([49])}
# {'index': 14, 'op_name': 'FULLY_CONNECTED', 'inputs': array([49, 33, -1]), 'outputs': array([50])}
# {'index': 15, 'op_name': 'ADD', 'inputs': array([50, 46]), 'outputs': array([51])}
# {'index': 16, 'op_name': 'ADD', 'inputs': array([51, 16]), 'outputs': array([52])}
# {'index': 17, 'op_name': 'SPLIT', 'inputs': array([12, 52]), 'outputs': array([53, 54, 55, 56])}
# {'index': 18, 'op_name': 'LOGISTIC', 'inputs': array([53]), 'outputs': array([57])}
# {'index': 19, 'op_name': 'LOGISTIC', 'inputs': array([54]), 'outputs': array([58])}
# {'index': 20, 'op_name': 'MUL', 'inputs': array([58, 43]), 'outputs': array([59])}
# {'index': 21, 'op_name': 'LOGISTIC', 'inputs': array([56]), 'outputs': array([60])}
# {'index': 22, 'op_name': 'TANH', 'inputs': array([55]), 'outputs': array([61])}
# {'index': 23, 'op_name': 'MUL', 'inputs': array([57, 61]), 'outputs': array([62])}
# {'index': 24, 'op_name': 'ADD', 'inputs': array([59, 62]), 'outputs': array([63])}
# {'index': 25, 'op_name': 'TANH', 'inputs': array([63]), 'outputs': array([64])}
# {'index': 26, 'op_name': 'MUL', 'inputs': array([60, 64]), 'outputs': array([65])}
# {'index': 27, 'op_name': 'ZEROS_LIKE', 'inputs': array([65]), 'outputs': array([66])}
# {'index': 28, 'op_name': 'TRANSPOSE', 'inputs': array([45, 14]), 'outputs': array([67])}
# {'index': 29, 'op_name': 'WHILE', 'inputs': array([13, 13, 48, 66, 43, 43, 67, 47]), 'outputs': array([68, 69, 70, 71, 72, 73, 74, 75])}
# {'index': 30, 'op_name': 'FlexTensorListStack', 'inputs': array([70, 11]), 'outputs': array([76])}
# {'index': 31, 'op_name': 'TRANSPOSE', 'inputs': array([76, 14]), 'outputs': array([77])}
# {'index': 32, 'op_name': 'SHAPE', 'inputs': array([77]), 'outputs': array([78])}
# {'index': 33, 'op_name': 'STRIDED_SLICE', 'inputs': array([78, 21, 22, 22]), 'outputs': array([79])}
# {'index': 34, 'op_name': 'PACK', 'inputs': array([79, 25]), 'outputs': array([80])}
# {'index': 35, 'op_name': 'FILL', 'inputs': array([80, 23]), 'outputs': array([81])}
# {'index': 36, 'op_name': 'FULLY_CONNECTED', 'inputs': array([81, 28, -1]), 'outputs': array([82])}
# {'index': 37, 'op_name': 'SHAPE', 'inputs': array([76]), 'outputs': array([83])}
# {'index': 38, 'op_name': 'STRIDED_SLICE', 'inputs': array([83, 21, 22, 22]), 'outputs': array([84])}
# {'index': 39, 'op_name': 'FlexTensorListReserve', 'inputs': array([10, 84]), 'outputs': array([85])}
# {'index': 40, 'op_name': 'STRIDED_SLICE', 'inputs': array([76,  2,  5,  4]), 'outputs': array([86])}
# {'index': 41, 'op_name': 'FULLY_CONNECTED', 'inputs': array([86, 29, -1]), 'outputs': array([87])}
# {'index': 42, 'op_name': 'ADD', 'inputs': array([87, 82]), 'outputs': array([88])}
# {'index': 43, 'op_name': 'ADD', 'inputs': array([88, 18]), 'outputs': array([89])}
# {'index': 44, 'op_name': 'SPLIT', 'inputs': array([12, 89]), 'outputs': array([90, 91, 92, 93])}
# {'index': 45, 'op_name': 'LOGISTIC', 'inputs': array([90]), 'outputs': array([94])}
# {'index': 46, 'op_name': 'LOGISTIC', 'inputs': array([91]), 'outputs': array([95])}
# {'index': 47, 'op_name': 'MUL', 'inputs': array([95, 81]), 'outputs': array([96])}
# {'index': 48, 'op_name': 'LOGISTIC', 'inputs': array([93]), 'outputs': array([97])}
# {'index': 49, 'op_name': 'TANH', 'inputs': array([92]), 'outputs': array([98])}
# {'index': 50, 'op_name': 'MUL', 'inputs': array([94, 98]), 'outputs': array([99])}
# {'index': 51, 'op_name': 'ADD', 'inputs': array([96, 99]), 'outputs': array([100])}
# {'index': 52, 'op_name': 'TANH', 'inputs': array([100]), 'outputs': array([101])}
# {'index': 53, 'op_name': 'MUL', 'inputs': array([ 97, 101]), 'outputs': array([102])}
# {'index': 54, 'op_name': 'ZEROS_LIKE', 'inputs': array([102]), 'outputs': array([103])}
# {'index': 55, 'op_name': 'WHILE', 'inputs': array([ 13,  13,  85, 103,  81,  81,  84,  67,  76]), 'outputs': array([104, 105, 106, 107, 108, 109, 110, 111, 112])}
# {'index': 56, 'op_name': 'FlexTensorListStack', 'inputs': array([106,  10]), 'outputs': array([113])}
# {'index': 57, 'op_name': 'TRANSPOSE', 'inputs': array([113,  14]), 'outputs': array([114])}
# {'index': 58, 'op_name': 'SHAPE', 'inputs': array([114]), 'outputs': array([115])}
# {'index': 59, 'op_name': 'STRIDED_SLICE', 'inputs': array([115,  21,  22,  22]), 'outputs': array([116])}
# {'index': 60, 'op_name': 'PACK', 'inputs': array([116,  26]), 'outputs': array([117])}
# {'index': 61, 'op_name': 'FILL', 'inputs': array([117,  23]), 'outputs': array([118])}
# {'index': 62, 'op_name': 'FlexTensorListReserve', 'inputs': array([ 9, 12]), 'outputs': array([119])}
# {'index': 63, 'op_name': 'FULLY_CONNECTED', 'inputs': array([118,  30,  -1]), 'outputs': array([120])}
# {'index': 64, 'op_name': 'SHAPE', 'inputs': array([113]), 'outputs': array([121])}
# {'index': 65, 'op_name': 'STRIDED_SLICE', 'inputs': array([121,  21,  22,  22]), 'outputs': array([122])}
# {'index': 66, 'op_name': 'STRIDED_SLICE', 'inputs': array([113,   2,   6,   4]), 'outputs': array([123])}
# {'index': 67, 'op_name': 'FULLY_CONNECTED', 'inputs': array([123,  31,  -1]), 'outputs': array([124])}
# {'index': 68, 'op_name': 'ADD', 'inputs': array([124, 120]), 'outputs': array([125])}
# {'index': 69, 'op_name': 'ADD', 'inputs': array([125,  17]), 'outputs': array([126])}
# {'index': 70, 'op_name': 'SPLIT', 'inputs': array([ 12, 126]), 'outputs': array([127, 128, 129, 130])}
# {'index': 71, 'op_name': 'LOGISTIC', 'inputs': array([127]), 'outputs': array([131])}
# {'index': 72, 'op_name': 'LOGISTIC', 'inputs': array([128]), 'outputs': array([132])}
# {'index': 73, 'op_name': 'MUL', 'inputs': array([132, 118]), 'outputs': array([133])}
# {'index': 74, 'op_name': 'LOGISTIC', 'inputs': array([130]), 'outputs': array([134])}
# {'index': 75, 'op_name': 'TANH', 'inputs': array([129]), 'outputs': array([135])}
# {'index': 76, 'op_name': 'MUL', 'inputs': array([131, 135]), 'outputs': array([136])}
# {'index': 77, 'op_name': 'ADD', 'inputs': array([133, 136]), 'outputs': array([137])}
# {'index': 78, 'op_name': 'TANH', 'inputs': array([137]), 'outputs': array([138])}
# {'index': 79, 'op_name': 'MUL', 'inputs': array([134, 138]), 'outputs': array([139])}
# {'index': 80, 'op_name': 'ZEROS_LIKE', 'inputs': array([139]), 'outputs': array([140])}
# {'index': 81, 'op_name': 'WHILE', 'inputs': array([ 13,  13, 119, 140, 118, 118, 122,  67, 113]), 'outputs': array([141, 142, 143, 144, 145, 146, 147, 148, 149])}
# {'index': 82, 'op_name': 'FlexTensorListStack', 'inputs': array([143,   9]), 'outputs': array([150])}
# {'index': 83, 'op_name': 'STRIDED_SLICE', 'inputs': array([150,   7,   8,   4]), 'outputs': array([151])}
# {'index': 84, 'op_name': 'FULLY_CONNECTED', 'inputs': array([151,  34,  19]), 'outputs': array([152])}
# {'index': 85, 'op_name': 'FULLY_CONNECTED', 'inputs': array([152,  35,  20]), 'outputs': array([153])}
# {'index': 86, 'op_name': 'SOFTMAX', 'inputs': array([153]), 'outputs': array([154])}
# {'index': 87, 'op_name': 'DELEGATE', 'inputs': array([ 9, 11, 12, 15]), 'outputs': array([ 48, 119])}
# {'index': 88, 'op_name': 'DELEGATE', 'inputs': array([11, 70]), 'outputs': array([76])}
# {'index': 89, 'op_name': 'DELEGATE', 'inputs': array([10, 84]), 'outputs': array([85])}
# {'index': 90, 'op_name': 'DELEGATE', 'inputs': array([ 10, 106]), 'outputs': array([113])}
# {'index': 91, 'op_name': 'DELEGATE', 'inputs': array([  9, 143]), 'outputs': array([150])}

# %%
import tensorflow as tf
import numpy as np

interpreter = tf.lite.Interpreter(model_path='mymodele.tflite')
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Prepare dummy input (matching [1, 930, 13])
dummy_input = np.zeros((1, 930, 13), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], dummy_input)

# Run inference
interpreter.invoke()

# Get output
output = interpreter.get_tensor(output_details[0]['index'])
print("Output:", output)
# Out:
# Output: [[0.1266597  0.1602299  0.16510385 0.1393406  0.11905956 0.13949294
#   0.1501134 ]]

# %%
import tensorflow as tf
import numpy as np

interpreter = tf.lite.Interpreter(model_path='mymodele.tflite')
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

dummy_input = np.zeros((1, 930, 13), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], dummy_input)
interpreter.invoke()
output = interpreter.get_tensor(output_details[0]['index'])
print("Dummy output:", output)
# Out:
# Dummy output: [[0.1266597  0.1602299  0.16510385 0.1393406  0.11905956 0.13949294
#   0.1501134 ]]
